# %%
import numpy as np
import keras
import os
from pathlib import Path

# %%
batch_size = 64 
epochs = 100  
latent_dim = 256  
num_samples = 10000  

data_path = os.path.join("ukr.txt")

# %%
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")

    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32",
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 72
# Number of unique output tokens: 96
# Max sequence length for inputs: 15
# Max sequence length for outputs: 54

# %%
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

encoder_states = [state_h, state_c]

decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=50,
    validation_split=0.2,
)
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8852 - loss: 0.3912 - val_accuracy: 0.8584 - val_loss: 0.4983
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.8879 - loss: 0.3833 - val_accuracy: 0.8588 - val_loss: 0.4932
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.8902 - loss: 0.3747 - val_accuracy: 0.8605 - val_loss: 0.4921
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.8915 - loss: 0.3721 - val_accuracy: 0.8604 - val_loss: 0.4905
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.8930 - loss: 0.3646 - val_accuracy: 0.8597 - val_loss: 0.4931
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.8946 - loss: 0.3609 - val_accuracy: 0.8617 - val_loss: 0.4876
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.8961 - loss: 0.3563 - val_accuracy: 0.8630 - val_loss: 0.4864
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.8983 - loss: 0.3487 - val_accuracy: 0.8633 - val_loss: 0.4826
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8987 - loss: 0.3453 - val_accuracy: 0.8637 - val_loss: 0.4840
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.9012 - loss: 0.3385 - val_accuracy: 0.8633 - val_loss: 0.4845
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9024 - loss: 0.3351 - val_accuracy: 0.8652 - val_loss: 0.4797
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.9040 - loss: 0.3293 - val_accuracy: 0.8638 - val_loss: 0.4849
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.9047 - loss: 0.3259 - val_accuracy: 0.8652 - val_loss: 0.4824
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.9060 - loss: 0.3224 - val_accuracy: 0.8638 - val_loss: 0.4882
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9080 - loss: 0.3146 - val_accuracy: 0.8664 - val_loss: 0.4788
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.9091 - loss: 0.3099 - val_accuracy: 0.8667 - val_loss: 0.4807
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.9096 - loss: 0.3096 - val_accuracy: 0.8663 - val_loss: 0.4802
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.9117 - loss: 0.3034 - val_accuracy: 0.8661 - val_loss: 0.4813
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.9127 - loss: 0.2985 - val_accuracy: 0.8668 - val_loss: 0.4798
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.9138 - loss: 0.2956 - val_accuracy: 0.8683 - val_loss: 0.4807
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.9147 - loss: 0.2934 - val_accuracy: 0.8678 - val_loss: 0.4811
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.9151 - loss: 0.2886 - val_accuracy: 0.8689 - val_loss: 0.4794
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.9168 - loss: 0.2836 - val_accuracy: 0.8674 - val_loss: 0.4842
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9170 - loss: 0.2841 - val_accuracy: 0.8685 - val_loss: 0.4833
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9200 - loss: 0.2739 - val_accuracy: 0.8684 - val_loss: 0.4837
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.9206 - loss: 0.2719 - val_accuracy: 0.8688 - val_loss: 0.4858
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.9207 - loss: 0.2693 - val_accuracy: 0.8678 - val_loss: 0.4865
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9226 - loss: 0.2641 - val_accuracy: 0.8688 - val_loss: 0.4866
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9233 - loss: 0.2622 - val_accuracy: 0.8684 - val_loss: 0.4881
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9242 - loss: 0.2573 - val_accuracy: 0.8680 - val_loss: 0.4899
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9267 - loss: 0.2496 - val_accuracy: 0.8702 - val_loss: 0.4879
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9273 - loss: 0.2504 - val_accuracy: 0.8694 - val_loss: 0.4882
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9278 - loss: 0.2457 - val_accuracy: 0.8694 - val_loss: 0.4903
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.9289 - loss: 0.2417 - val_accuracy: 0.8696 - val_loss: 0.4925
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.9299 - loss: 0.2380 - val_accuracy: 0.8704 - val_loss: 0.4913
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9308 - loss: 0.2358 - val_accuracy: 0.8702 - val_loss: 0.4950
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.9317 - loss: 0.2321 - val_accuracy: 0.8694 - val_loss: 0.4966
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.9333 - loss: 0.2285 - val_accuracy: 0.8691 - val_loss: 0.4997
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9329 - loss: 0.2282 - val_accuracy: 0.8677 - val_loss: 0.5089
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.9345 - loss: 0.2222 - val_accuracy: 0.8698 - val_loss: 0.4985
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.9356 - loss: 0.2204 - val_accuracy: 0.8703 - val_loss: 0.5037
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.9367 - loss: 0.2150 - val_accuracy: 0.8682 - val_loss: 0.5077
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9365 - loss: 0.2159 - val_accuracy: 0.8703 - val_loss: 0.5041
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.9377 - loss: 0.2117 - val_accuracy: 0.8703 - val_loss: 0.5077
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9394 - loss: 0.2068 - val_accuracy: 0.8696 - val_loss: 0.5152
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.9399 - loss: 0.2046 - val_accuracy: 0.8695 - val_loss: 0.5131
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.9409 - loss: 0.2016 - val_accuracy: 0.8689 - val_loss: 0.5181
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.9417 - loss: 0.1989 - val_accuracy: 0.8692 - val_loss: 0.5215
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.9423 - loss: 0.1971 - val_accuracy: 0.8695 - val_loss: 0.5230
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.9428 - loss: 0.1946 - val_accuracy: 0.8690 - val_loss: 0.5241

# %%
encoder_inputs = model.input[0]
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1] 
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq, verbose=0)

    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index["\t"]] = 1.0
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value, verbose=0
        )

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        states_value = [h, c]
    return decoded_sentence

# %%
import random

num_sequences = len(input_texts)
sequence_indices = list(range(num_sequences))

random.shuffle(sequence_indices)

for seq_index in sequence_indices[:20]:
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("----------------------------------------")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# ----------------------------------------
# Input sentence: It's a sequel.
# Decoded sentence: Це прановля.
#
# ----------------------------------------
# Input sentence: I feel guilty.
# Decoded sentence: Я почуваюся у божеві.
#
# ----------------------------------------
# Input sentence: Any questions?
# Decoded sentence: Ми можемо заплачити.
#
# ----------------------------------------
# Input sentence: I saved you.
# Decoded sentence: Я запитаю Тома.
#
# ----------------------------------------
# Input sentence: I like fish.
# Decoded sentence: Мені подобається жино.
#
# ----------------------------------------
# Input sentence: Tom graduated.
# Decoded sentence: Том заплатив нідавій.
#
# ----------------------------------------
# Input sentence: Go sit down.
# Decoded sentence: Педепрай верарають.
#
# ----------------------------------------
# Input sentence: Take it away.
# Decoded sentence: Відьміть це.
#
# ----------------------------------------
# Input sentence: It's a secret.
# Decoded sentence: Це прановло.
#
# ----------------------------------------
# Input sentence: It's a secret.
# Decoded sentence: Це прановло.
#
# ----------------------------------------
# Input sentence: Be realistic.
# Decoded sentence: Будьте реалістами.
#
# ----------------------------------------
# Input sentence: It's my CD.
# Decoded sentence: Це мій комарав"".
#
# ----------------------------------------
# Input sentence: Stop reading.
# Decoded sentence: Перестань кричати.
#
# ----------------------------------------
# Input sentence: It snowed.
# Decoded sentence: Це мене брив.
#
# ----------------------------------------
# Input sentence: I borrowed it.
# Decoded sentence: Я витак.
#
# ----------------------------------------
# Input sentence: I'm not old.
# Decoded sentence: Я не поверну.
#
# ----------------------------------------
# Input sentence: Awesome!
# Decoded sentence: Чудово!
#
# ----------------------------------------
# Input sentence: I was shocked.
# Decoded sentence: Я був у порядку.
#
# ----------------------------------------
# Input sentence: You missed.
# Decoded sentence: Ти мене вілинийся.
#
# ----------------------------------------
# Input sentence: I'm drunk.
# Decoded sentence: Я невислава.
